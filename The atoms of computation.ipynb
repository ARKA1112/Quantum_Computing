# %%
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *

# qiskit-ibmq-provider has been deprecated.
# Please see the Migration Guides in https://ibm.biz/provider_migration_guide for more detail.
from qiskit_ibm_runtime import QiskitRuntimeService, Sampler, Estimator, Session, Options

# Loading your IBM Quantum account(s)
service = QiskitRuntimeService(channel="ibm_quantum")

# Invoke a primitive. For more details see https://qiskit.org/documentation/partners/qiskit_ibm_runtime/tutorials.html
# result = Sampler("ibmq_qasm_simulator").run(circuits).result()

# %%
from qiskit import QuantumCircuit
#Create quantum circuit with 3 qubits and 3 classical bits

qc = QuantumCircuit(3,3)
qc.draw()

# %%
#Next we need a way to tell out quantum computer to measure our qubits and record the results.

from qiskit import QuantumCircuit
qc = QuantumCircuit(3,3)

#Measure qubits 0,1,1 to classical bits 0,1,2 

qc.measure([0,1,2],[0,1,2])
qc.draw()

# %%
#import Quantum simulator

from qiskit.providers.aer import AerSimulator
sim=AerSimulator()

# %%
job = sim.run(qc) #run the experiment
result = job.result() #retrieve the result
result.get_counts()
# Out:
# {'000': 1024}

# %%
#In the returned dictionary the keys are bit-strings, and hte values are the number of times 
#that bit-string was measured.

# Create quantum circuit with 3 qubits and 3 classical bits:

qc = QuantumCircuit(3,3)
qc.x([0,1])  # Perform X-gates on qubits 0 & 1
qc.measure([0,1,2], [0,1,2])
qc.draw()

# %%
job = sim.run(qc)
result = job.result()
result.get_counts()
# Out:
# {'011': 1024}

# %% [markdown]
# ## The main funda is that all are getting 0 as input, but the
# x or NOT gate reverses it. and the order is always decreasing

# %%
#modify the above code to create a quantum circuit that encodes the numbers 6 and 4

qc = QuantumCircuit(3,3)
qc.x([2])   #this is for 4
qc.measure([0,1,2],[0,1,2])
qc.draw()

# %%
job = sim.run(qc)
results = job.result()
results.get_counts()
# Out:
# {'100': 1024}

# %%
#Now lets do it for 6

qc = QuantumCircuit(3,3)
qc.x([0,2])
qc.measure([0,1,2],[0,1,2])
qc.draw()

# %%
job = sim.run(qc)
results = job.result()
results.get_counts()
# Out:
# {'101': 1024}
